# %%
import requests
import os
from PIL import Image
from io import BytesIO
import time
import zipfile
from google.colab import files

# Create folder for screenshots
os.makedirs("screenshots", exist_ok=True)

# 150 Top websites - diverse, high-quality, good UI elements
urls = [
    # E-commerce & Shopping
    "https://amazon.com", "https://ebay.com", "https://etsy.com", "https://shopify.com",
    "https://walmart.com", "https://target.com", "https://bestbuy.com", "https://alibaba.com",
    "https://wayfair.com", "https://ikea.com", "https://zappos.com", "https://asos.com",

    # Tech & SaaS
    "https://stripe.com", "https://github.com", "https://gitlab.com", "https://atlassian.com",
    "https://slack.com", "https://notion.so", "https://trello.com", "https://asana.com",
    "https://monday.com", "https://dropbox.com", "https://zoom.us", "https://microsoft.com",
    "https://google.com", "https://apple.com", "https://salesforce.com", "https://hubspot.com",
    "https://mailchimp.com", "https://canva.com", "https://figma.com", "https://adobe.com",

    # Social Media & Content
    "https://twitter.com", "https://facebook.com", "https://instagram.com", "https://linkedin.com",
    "https://reddit.com", "https://pinterest.com", "https://tiktok.com", "https://snapchat.com",
    "https://discord.com", "https://twitch.tv", "https://youtube.com", "https://vimeo.com",
    "https://medium.com", "https://substack.com", "https://wordpress.com", "https://tumblr.com",

    # Streaming & Entertainment
    "https://netflix.com", "https://spotify.com", "https://hulu.com", "https://disneyplus.com",
    "https://primevideo.com", "https://hbomax.com", "https://paramount.com", "https://peacocktv.com",
    "https://soundcloud.com", "https://pandora.com", "https://deezer.com", "https://tidal.com",

    # Travel & Booking
    "https://airbnb.com", "https://booking.com", "https://expedia.com", "https://kayak.com",
    "https://tripadvisor.com", "https://hotels.com", "https://priceline.com", "https://vrbo.com",

    # Food & Delivery
    "https://doordash.com", "https://ubereats.com", "https://grubhub.com", "https://instacart.com",
    "https://hellofresh.com", "https://bluebottlecoffee.com", "https://starbucks.com", "https://chipotle.com",

    # Finance & Banking
    "https://paypal.com", "https://venmo.com", "https://coinbase.com", "https://robinhood.com",
    "https://wellsfargo.com", "https://chase.com", "https://bankofamerica.com", "https://ally.com",
    "https://mint.com", "https://creditkarma.com", "https://turbotax.com", "https://quickbooks.com",

    # News & Media
    "https://nytimes.com", "https://wsj.com", "https://cnn.com", "https://bbc.com",
    "https://theguardian.com", "https://reuters.com", "https://forbes.com", "https://bloomberg.com",
    "https://techcrunch.com", "https://theverge.com", "https://wired.com", "https://mashable.com",

    # Education & Learning
    "https://coursera.org", "https://udemy.com", "https://khanacademy.org", "https://duolingo.com",
    "https://skillshare.com", "https://masterclass.com", "https://codecademy.com", "https://edx.org",

    # Health & Fitness
    "https://peloton.com", "https://myfitnesspal.com", "https://fitbit.com", "https://headspace.com",
    "https://calm.com", "https://webmd.com", "https://cvs.com", "https://walgreens.com",

    # Design & Creative
    "https://behance.net", "https://dribbble.com", "https://unsplash.com", "https://pexels.com",
    "https://awwwards.com", "https://designinspiration.com", "https://invisionapp.com", "https://sketch.com",

    # Business & Productivity
    "https://shopify.com", "https://squarespace.com", "https://wix.com", "https://godaddy.com",
    "https://namecheap.com", "https://airtable.com", "https://calendly.com", "https://loom.com",
    "https://grammarly.com", "https://evernote.com", "https://notion.so", "https://roamresearch.com",

    # Developer Tools
    "https://stackoverflow.com", "https://dev.to", "https://npmjs.com", "https://docker.com",
    "https://kubernetes.io", "https://aws.amazon.com", "https://vercel.com", "https://netlify.com",

    # Gaming
    "https://steam.com", "https://epicgames.com", "https://ea.com", "https://roblox.com",
    "https://minecraft.net", "https://playstation.com", "https://xbox.com", "https://nintendo.com",

    # Real Estate & Auto
    "https://zillow.com", "https://redfin.com", "https://realtor.com", "https://trulia.com",
    "https://carvana.com", "https://tesla.com", "https://autotrader.com", "https://carmax.com"
]

def capture_screenshots_free(url_list):
    """Capture 150 diverse website screenshots"""

    for i, url in enumerate(url_list):
        try:
            print(f"Capturing {i+1}/{len(url_list)}: {url}")

            # Free API - no authentication required
            api_url = f"https://image.thum.io/get/width/1920/crop/1080/noanimate/{url}"

            response = requests.get(api_url, timeout=60)
            time.sleep(3)  # 3 second delay to be safe with free API

            if response.status_code == 200:
                filename = f"screenshots/screenshot_{i+1:03d}.png"

                with open(filename, 'wb') as f:
                    f.write(response.content)

                print(f" Saved: {filename}")
            else:
                print(f" Failed: {response.status_code}")

        except Exception as e:
            print(f"Error: {str(e)}")
            time.sleep(5)  # Wait longer if error
            continue

    total = len([f for f in os.listdir('screenshots') if f.endswith('.png')])
    print(f"\n Done! Captured {total} screenshots!")
    return total

def zip_and_download():
    """Zip the screenshots folder and download it"""

    print("\n Creating ZIP file...")

    # Create zip file
    zip_filename = "website_screenshots.zip"
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk("screenshots"):
            for file in files:
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.basename(file_path))

    print(f"ZIP created: {zip_filename}")

    # Download the zip file
    print(" Downloading...")
    files.download(zip_filename)
    print(" Download complete!")

# Run the whole process
print(f"Starting capture of {len(urls)} websites...")

total_captured = capture_screenshots_free(urls)

print(f"\n  Summary: {total_captured}/{len(urls)} screenshots captured")
print("\nPreparing download...")

# Zip and download
zip_and_download()

print("\n All done! Check your downloads folder for 'website_screenshots.zip'")
# Out:
# Starting capture of 160 websites...
# Capturing 1/160: https://amazon.com
#  Saved: screenshots/screenshot_001.png
# Capturing 2/160: https://ebay.com
#  Saved: screenshots/screenshot_002.png
# Capturing 3/160: https://etsy.com
#  Saved: screenshots/screenshot_003.png
# Capturing 4/160: https://shopify.com
#  Saved: screenshots/screenshot_004.png
# Capturing 5/160: https://walmart.com
#  Saved: screenshots/screenshot_005.png
# Capturing 6/160: https://target.com
#  Saved: screenshots/screenshot_006.png
# Capturing 7/160: https://bestbuy.com
#  Saved: screenshots/screenshot_007.png
# Capturing 8/160: https://alibaba.com
#  Saved: screenshots/screenshot_008.png
# Capturing 9/160: https://wayfair.com
#  Saved: screenshots/screenshot_009.png
# Capturing 10/160: https://ikea.com
#  Saved: screenshots/screenshot_010.png
# Capturing 11/160: https://zappos.com
#  Saved: screenshots/screenshot_011.png
# Capturing 12/160: https://asos.com
#  Saved: screenshots/screenshot_012.png
# Capturing 13/160: https://stripe.com
#  Saved: screenshots/screenshot_013.png
# Capturing 14/160: https://github.com
#  Saved: screenshots/screenshot_014.png
# Capturing 15/160: https://gitlab.com
#  Saved: screenshots/screenshot_015.png
# Capturing 16/160: https://atlassian.com
#  Saved: screenshots/screenshot_016.png
# Capturing 17/160: https://slack.com
#  Saved: screenshots/screenshot_017.png
# Capturing 18/160: https://notion.so
#  Saved: screenshots/screenshot_018.png
# Capturing 19/160: https://trello.com
#  Saved: screenshots/screenshot_019.png
# Capturing 20/160: https://asana.com
#  Saved: screenshots/screenshot_020.png
# Capturing 21/160: https://monday.com
#  Saved: screenshots/screenshot_021.png
# Capturing 22/160: https://dropbox.com
#  Saved: screenshots/screenshot_022.png
# Capturing 23/160: https://zoom.us
#  Saved: screenshots/screenshot_023.png
# Capturing 24/160: https://microsoft.com
#  Saved: screenshots/screenshot_024.png
# Capturing 25/160: https://google.com
#  Saved: screenshots/screenshot_025.png
# Capturing 26/160: https://apple.com
#  Saved: screenshots/screenshot_026.png
# Capturing 27/160: https://salesforce.com
#  Saved: screenshots/screenshot_027.png
# Capturing 28/160: https://hubspot.com
#  Saved: screenshots/screenshot_028.png
# Capturing 29/160: https://mailchimp.com
#  Saved: screenshots/screenshot_029.png
# Capturing 30/160: https://canva.com
#  Saved: screenshots/screenshot_030.png
# Capturing 31/160: https://figma.com
#  Saved: screenshots/screenshot_031.png
# Capturing 32/160: https://adobe.com
#  Saved: screenshots/screenshot_032.png
# Capturing 33/160: https://twitter.com
#  Saved: screenshots/screenshot_033.png
# Capturing 34/160: https://facebook.com
#  Saved: screenshots/screenshot_034.png
# Capturing 35/160: https://instagram.com
#  Saved: screenshots/screenshot_035.png
# Capturing 36/160: https://linkedin.com
#  Saved: screenshots/screenshot_036.png
# Capturing 37/160: https://reddit.com
#  Saved: screenshots/screenshot_037.png
# Capturing 38/160: https://pinterest.com
#  Saved: screenshots/screenshot_038.png
# Capturing 39/160: https://tiktok.com
#  Saved: screenshots/screenshot_039.png
# Capturing 40/160: https://snapchat.com
#  Saved: screenshots/screenshot_040.png
# Capturing 41/160: https://discord.com
#  Saved: screenshots/screenshot_041.png
# Capturing 42/160: https://twitch.tv
#  Saved: screenshots/screenshot_042.png
# Capturing 43/160: https://youtube.com
#  Saved: screenshots/screenshot_043.png
# Capturing 44/160: https://vimeo.com
#  Saved: screenshots/screenshot_044.png
# Capturing 45/160: https://medium.com
#  Saved: screenshots/screenshot_045.png
# Capturing 46/160: https://substack.com
#  Saved: screenshots/screenshot_046.png
# Capturing 47/160: https://wordpress.com
#  Saved: screenshots/screenshot_047.png
# Capturing 48/160: https://tumblr.com
#  Saved: screenshots/screenshot_048.png
# Capturing 49/160: https://netflix.com
#  Saved: screenshots/screenshot_049.png
# Capturing 50/160: https://spotify.com
#  Saved: screenshots/screenshot_050.png
# Capturing 51/160: https://hulu.com
#  Saved: screenshots/screenshot_051.png
# Capturing 52/160: https://disneyplus.com
#  Saved: screenshots/screenshot_052.png
# Capturing 53/160: https://primevideo.com
#  Saved: screenshots/screenshot_053.png
# Capturing 54/160: https://hbomax.com
#  Saved: screenshots/screenshot_054.png
# Capturing 55/160: https://paramount.com
#  Saved: screenshots/screenshot_055.png
# Capturing 56/160: https://peacocktv.com
#  Saved: screenshots/screenshot_056.png
# Capturing 57/160: https://soundcloud.com
#  Saved: screenshots/screenshot_057.png
# Capturing 58/160: https://pandora.com
#  Saved: screenshots/screenshot_058.png
# Capturing 59/160: https://deezer.com
#  Saved: screenshots/screenshot_059.png
# Capturing 60/160: https://tidal.com
#  Saved: screenshots/screenshot_060.png
# Capturing 61/160: https://airbnb.com
#  Saved: screenshots/screenshot_061.png
# Capturing 62/160: https://booking.com
#  Saved: screenshots/screenshot_062.png
# Capturing 63/160: https://expedia.com
#  Saved: screenshots/screenshot_063.png
# Capturing 64/160: https://kayak.com
#  Saved: screenshots/screenshot_064.png
# Capturing 65/160: https://tripadvisor.com
#  Saved: screenshots/screenshot_065.png
# Capturing 66/160: https://hotels.com
#  Saved: screenshots/screenshot_066.png
# Capturing 67/160: https://priceline.com
#  Saved: screenshots/screenshot_067.png
# Capturing 68/160: https://vrbo.com
#  Saved: screenshots/screenshot_068.png
# Capturing 69/160: https://doordash.com
#  Saved: screenshots/screenshot_069.png
# Capturing 70/160: https://ubereats.com
#  Saved: screenshots/screenshot_070.png
# Capturing 71/160: https://grubhub.com
#  Saved: screenshots/screenshot_071.png
# Capturing 72/160: https://instacart.com
#  Saved: screenshots/screenshot_072.png
# Capturing 73/160: https://hellofresh.com
#  Saved: screenshots/screenshot_073.png
# Capturing 74/160: https://bluebottlecoffee.com
#  Saved: screenshots/screenshot_074.png
# Capturing 75/160: https://starbucks.com
#  Failed: 502
# Capturing 76/160: https://chipotle.com
#  Saved: screenshots/screenshot_076.png
# Capturing 77/160: https://paypal.com
#  Saved: screenshots/screenshot_077.png
# Capturing 78/160: https://venmo.com
#  Saved: screenshots/screenshot_078.png
# Capturing 79/160: https://coinbase.com
#  Saved: screenshots/screenshot_079.png
# Capturing 80/160: https://robinhood.com
#  Saved: screenshots/screenshot_080.png
# Capturing 81/160: https://wellsfargo.com
#  Saved: screenshots/screenshot_081.png
# Capturing 82/160: https://chase.com
#  Saved: screenshots/screenshot_082.png
# Capturing 83/160: https://bankofamerica.com
#  Saved: screenshots/screenshot_083.png
# Capturing 84/160: https://ally.com
#  Saved: screenshots/screenshot_084.png
# Capturing 85/160: https://mint.com
#  Saved: screenshots/screenshot_085.png
# Capturing 86/160: https://creditkarma.com
#  Saved: screenshots/screenshot_086.png
# Capturing 87/160: https://turbotax.com
#  Saved: screenshots/screenshot_087.png
# Capturing 88/160: https://quickbooks.com
#  Saved: screenshots/screenshot_088.png
# Capturing 89/160: https://nytimes.com
#  Saved: screenshots/screenshot_089.png
# Capturing 90/160: https://wsj.com
#  Saved: screenshots/screenshot_090.png
# Capturing 91/160: https://cnn.com
#  Saved: screenshots/screenshot_091.png
# Capturing 92/160: https://bbc.com
#  Saved: screenshots/screenshot_092.png
# Capturing 93/160: https://theguardian.com
#  Saved: screenshots/screenshot_093.png
# Capturing 94/160: https://reuters.com
#  Saved: screenshots/screenshot_094.png
# Capturing 95/160: https://forbes.com
#  Saved: screenshots/screenshot_095.png
# Capturing 96/160: https://bloomberg.com
#  Saved: screenshots/screenshot_096.png
# Capturing 97/160: https://techcrunch.com
#  Saved: screenshots/screenshot_097.png
# Capturing 98/160: https://theverge.com
#  Saved: screenshots/screenshot_098.png
# Capturing 99/160: https://wired.com
#  Saved: screenshots/screenshot_099.png
# Capturing 100/160: https://mashable.com
#  Saved: screenshots/screenshot_100.png
# Capturing 101/160: https://coursera.org
#  Saved: screenshots/screenshot_101.png
# Capturing 102/160: https://udemy.com
#  Saved: screenshots/screenshot_102.png
# Capturing 103/160: https://khanacademy.org
#  Saved: screenshots/screenshot_103.png
# Capturing 104/160: https://duolingo.com
#  Saved: screenshots/screenshot_104.png
# Capturing 105/160: https://skillshare.com
#  Saved: screenshots/screenshot_105.png
# Capturing 106/160: https://masterclass.com
#  Saved: screenshots/screenshot_106.png
# Capturing 107/160: https://codecademy.com
#  Saved: screenshots/screenshot_107.png
# Capturing 108/160: https://edx.org
#  Saved: screenshots/screenshot_108.png
# Capturing 109/160: https://peloton.com
#  Saved: screenshots/screenshot_109.png
# Capturing 110/160: https://myfitnesspal.com
#  Saved: screenshots/screenshot_110.png
# Capturing 111/160: https://fitbit.com
#  Saved: screenshots/screenshot_111.png
# Capturing 112/160: https://headspace.com
#  Failed: 502
# Capturing 113/160: https://calm.com
#  Saved: screenshots/screenshot_113.png
# Capturing 114/160: https://webmd.com
#  Saved: screenshots/screenshot_114.png
# Capturing 115/160: https://cvs.com
#  Saved: screenshots/screenshot_115.png
# Capturing 116/160: https://walgreens.com
#  Saved: screenshots/screenshot_116.png
# Capturing 117/160: https://behance.net
#  Saved: screenshots/screenshot_117.png
# Capturing 118/160: https://dribbble.com
#  Saved: screenshots/screenshot_118.png
# Capturing 119/160: https://unsplash.com
#  Saved: screenshots/screenshot_119.png
# Capturing 120/160: https://pexels.com
#  Saved: screenshots/screenshot_120.png
# Capturing 121/160: https://awwwards.com
#  Saved: screenshots/screenshot_121.png
# Capturing 122/160: https://designinspiration.com
#  Saved: screenshots/screenshot_122.png
# Capturing 123/160: https://invisionapp.com
#  Saved: screenshots/screenshot_123.png
# Capturing 124/160: https://sketch.com
#  Saved: screenshots/screenshot_124.png
# Capturing 125/160: https://shopify.com
#  Saved: screenshots/screenshot_125.png
# Capturing 126/160: https://squarespace.com
#  Saved: screenshots/screenshot_126.png
# Capturing 127/160: https://wix.com
#  Saved: screenshots/screenshot_127.png
# Capturing 128/160: https://godaddy.com
#  Saved: screenshots/screenshot_128.png
# Capturing 129/160: https://namecheap.com
#  Saved: screenshots/screenshot_129.png
# Capturing 130/160: https://airtable.com
#  Saved: screenshots/screenshot_130.png
# Capturing 131/160: https://calendly.com
#  Saved: screenshots/screenshot_131.png
# Capturing 132/160: https://loom.com
#  Saved: screenshots/screenshot_132.png
# Capturing 133/160: https://grammarly.com
#  Saved: screenshots/screenshot_133.png
# Capturing 134/160: https://evernote.com
#  Saved: screenshots/screenshot_134.png
# Capturing 135/160: https://notion.so
#  Saved: screenshots/screenshot_135.png
# Capturing 136/160: https://roamresearch.com
#  Saved: screenshots/screenshot_136.png
# Capturing 137/160: https://stackoverflow.com
#  Saved: screenshots/screenshot_137.png
# Capturing 138/160: https://dev.to
#  Saved: screenshots/screenshot_138.png
# Capturing 139/160: https://npmjs.com
#  Saved: screenshots/screenshot_139.png
# Capturing 140/160: https://docker.com
#  Saved: screenshots/screenshot_140.png
# Capturing 141/160: https://kubernetes.io
#  Saved: screenshots/screenshot_141.png
# Capturing 142/160: https://aws.amazon.com
#  Saved: screenshots/screenshot_142.png
# Capturing 143/160: https://vercel.com
#  Saved: screenshots/screenshot_143.png
# Capturing 144/160: https://netlify.com
#  Saved: screenshots/screenshot_144.png
# Capturing 145/160: https://steam.com
#  Saved: screenshots/screenshot_145.png
# Capturing 146/160: https://epicgames.com
#  Saved: screenshots/screenshot_146.png
# Capturing 147/160: https://ea.com
#  Saved: screenshots/screenshot_147.png
# Capturing 148/160: https://roblox.com
#  Saved: screenshots/screenshot_148.png
# Capturing 149/160: https://minecraft.net
#  Saved: screenshots/screenshot_149.png
# Capturing 150/160: https://playstation.com
#  Saved: screenshots/screenshot_150.png
# Capturing 151/160: https://xbox.com
#  Saved: screenshots/screenshot_151.png
# Capturing 152/160: https://nintendo.com
#  Saved: screenshots/screenshot_152.png
# Capturing 153/160: https://zillow.com
#  Saved: screenshots/screenshot_153.png
# Capturing 154/160: https://redfin.com
#  Saved: screenshots/screenshot_154.png
# Capturing 155/160: https://realtor.com
#  Saved: screenshots/screenshot_155.png
# Capturing 156/160: https://trulia.com
#  Saved: screenshots/screenshot_156.png
# Capturing 157/160: https://carvana.com
#  Saved: screenshots/screenshot_157.png
# Capturing 158/160: https://tesla.com
#  Saved: screenshots/screenshot_158.png
# Capturing 159/160: https://autotrader.com
#  Saved: screenshots/screenshot_159.png
# Capturing 160/160: https://carmax.com
#  Saved: screenshots/screenshot_160.png
#
#  Done! Captured 158 screenshots!
#
#   Summary: 158/160 screenshots captured
#
# Preparing download...
#
#  Creating ZIP file...
# ZIP created: website_screenshots.zip
#  Downloading...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4256979808.py in <cell line: 0>()
#     144
#     145 # Zip and download
# --> 146 zip_and_download()
#     147
#     148 print("\n All done! Check your downloads folder for 'website_screenshots.zip'")
#
# /tmp/ipython-input-4256979808.py in zip_and_download()
#     132     # Download the zip file
#     133     print(" Downloading...")
# --> 134     files.download(zip_filename)
#     135     print(" Download complete!")
#     136
#
# AttributeError: 'list' object has no attribute 'download'

# %%
# Just add this at the end - your screenshots are STILL THERE!

import zipfile
from google.colab import files as colab_files

def zip_and_download():
    """Zip the screenshots folder and download it"""

    print("\n📦 Creating ZIP file...")

    # Create zip file
    zip_filename = "website_screenshots.zip"
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files_list in os.walk("screenshots"):
            for file in files_list:
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.basename(file_path))

    print(f"ZIP created: {zip_filename}")

    # Download the zip file
    print("Downloading...")
    colab_files.download(zip_filename)
    print(" Download complete!")

# Run it NOW - your screenshots are already saved!
zip_and_download()
# Out:
# 📦 Creating ZIP file...
# ZIP created: website_screenshots.zip
# Downloading...
#  Download complete!
